# %%
import tensorflow as tf
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split

housing = fetch_california_housing()
X_train_full, X_test, y_train_full, y_test = train_test_split(
    housing.data, housing.target, random_state=42)
X_train, X_valid, y_train, y_valid = train_test_split(
    X_train_full, y_train_full, random_state=42)

# %%
tf.random.set_seed(42)
normalization_layer = tf.keras.layers.Normalization()
hidden_layer1 = tf.keras.layers.Dense(30, activation="relu")
hidden_layer2 = tf.keras.layers.Dense(30, activation="relu")
concat_layer = tf.keras.layers.Concatenate()
output_layer = tf.keras.layers.Dense(1)

input_ = tf.keras.layers.Input(shape=X_train.shape[1:])
normalized = normalization_layer(input_)
hidden1 = hidden_layer1(normalized)
hidden2 = hidden_layer2(hidden1)
concat = concat_layer([normalized, hidden2])
output = output_layer(concat)

model = tf.keras.Model(inputs=[input_], outputs=[output])

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 8)              │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ normalization             │ (None, 8)              │             17 │ input_layer[0][0]      │
# │ (Normalization)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 30)             │            270 │ normalization[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 30)             │            930 │ dense[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 38)             │              0 │ normalization[0][0],   │
# │                           │                        │                │ dense_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_2 (Dense)           │ (None, 1)              │             39 │ concatenate[0][0]      │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 1,256 (4.91 KB)
#  Trainable params: 1,239 (4.84 KB)
#  Non-trainable params: 17 (72.00 B)

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)
model.compile(loss="mse", optimizer=optimizer, metrics=["RootMeanSquaredError"])
normalization_layer.adapt(X_train)
history = model.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - RootMeanSquaredError: 1.6418 - loss: 2.9077 - val_RootMeanSquaredError: 2.1048 - val_loss: 4.4304
# Epoch 2/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - RootMeanSquaredError: 0.7049 - loss: 0.4982 - val_RootMeanSquaredError: 1.1261 - val_loss: 1.2680
# Epoch 3/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - RootMeanSquaredError: 0.6476 - loss: 0.4199 - val_RootMeanSquaredError: 0.8105 - val_loss: 0.6569
# Epoch 4/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.6286 - loss: 0.3956 - val_RootMeanSquaredError: 0.6033 - val_loss: 0.3639
# Epoch 5/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.6167 - loss: 0.3807 - val_RootMeanSquaredError: 0.8445 - val_loss: 0.7131
# Epoch 6/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.6075 - loss: 0.3693 - val_RootMeanSquaredError: 0.5851 - val_loss: 0.3424
# Epoch 7/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.5983 - loss: 0.3582 - val_RootMeanSquaredError: 0.9419 - val_loss: 0.8872
# Epoch 8/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - RootMeanSquaredError: 0.5910 - loss: 0.3495 - val_RootMeanSquaredError: 0.6050 - val_loss: 0.3661
# Epoch 9/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - RootMeanSquaredError: 0.5828 - loss: 0.3398 - val_RootMeanSquaredError: 1.1711 - val_loss: 1.3716
# Epoch 10/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5785 - loss: 0.3348 - val_RootMeanSquaredError: 1.0001 - val_loss: 1.0003
# Epoch 11/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5748 - loss: 0.3305 - val_RootMeanSquaredError: 1.7927 - val_loss: 3.2139
# Epoch 12/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5756 - loss: 0.3315 - val_RootMeanSquaredError: 1.3536 - val_loss: 1.8322
# Epoch 13/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5724 - loss: 0.3278 - val_RootMeanSquaredError: 1.7516 - val_loss: 3.0681
# Epoch 14/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5674 - loss: 0.3221 - val_RootMeanSquaredError: 1.1429 - val_loss: 1.3062
# Epoch 15/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5641 - loss: 0.3184 - val_RootMeanSquaredError: 1.5797 - val_loss: 2.4956
# Epoch 16/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5606 - loss: 0.3144 - val_RootMeanSquaredError: 0.8378 - val_loss: 0.7020
# Epoch 17/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - RootMeanSquaredError: 0.5565 - loss: 0.3098 - val_RootMeanSquaredError: 1.4788 - val_loss: 2.1869
# Epoch 18/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.5551 - loss: 0.3083 - val_RootMeanSquaredError: 0.9528 - val_loss: 0.9078
# Epoch 19/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.5544 - loss: 0.3074 - val_RootMeanSquaredError: 1.6848 - val_loss: 2.8387
# Epoch 20/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5529 - loss: 0.3058 - val_RootMeanSquaredError: 1.0091 - val_loss: 1.0183

# %%
loss_test, rmse_test = model.evaluate(X_test, y_test)
# Out:
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5555 - loss: 0.3088

# %%
import matplotlib
import matplotlib.pyplot as plt
y_pred = model.predict(X_test)
plt.scatter(y_pred,y_test)
# Out:
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
