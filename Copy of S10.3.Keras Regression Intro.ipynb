# %%
import tensorflow as tf
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split

housing = fetch_california_housing()
X_train_full, X_test, y_train_full, y_test = train_test_split(
    housing.data, housing.target, random_state=42)
X_train, X_valid, y_train, y_valid = train_test_split(
    X_train_full, y_train_full, random_state=42)

# %%
tf.random.set_seed(42)
norm_layer = tf.keras.layers.Normalization(input_shape=X_train.shape[1:])
model = tf.keras.Sequential([
    norm_layer,
    tf.keras.layers.Dense(50, activation="relu"),
    tf.keras.layers.Dense(50, activation="relu"),
    tf.keras.layers.Dense(50, activation="relu"),
    tf.keras.layers.Dense(1)
])
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)
model.compile(loss="mse", optimizer=optimizer, metrics=["RootMeanSquaredError"])
norm_layer.adapt(X_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/preprocessing/tf_data_layer.py:19: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
history = model.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - RootMeanSquaredError: 1.2746 - loss: 1.7492 - val_RootMeanSquaredError: 0.6126 - val_loss: 0.3753
# Epoch 2/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.6290 - loss: 0.3962 - val_RootMeanSquaredError: 0.6773 - val_loss: 0.4587
# Epoch 3/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.6037 - loss: 0.3647 - val_RootMeanSquaredError: 0.6173 - val_loss: 0.3811
# Epoch 4/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5914 - loss: 0.3499 - val_RootMeanSquaredError: 0.6691 - val_loss: 0.4477
# Epoch 5/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5831 - loss: 0.3401 - val_RootMeanSquaredError: 0.7583 - val_loss: 0.5749
# Epoch 6/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5764 - loss: 0.3324 - val_RootMeanSquaredError: 0.8845 - val_loss: 0.7824
# Epoch 7/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5714 - loss: 0.3266 - val_RootMeanSquaredError: 0.5472 - val_loss: 0.2995
# Epoch 8/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5651 - loss: 0.3194 - val_RootMeanSquaredError: 0.6392 - val_loss: 0.4086
# Epoch 9/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5584 - loss: 0.3119 - val_RootMeanSquaredError: 0.7546 - val_loss: 0.5694
# Epoch 10/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.5538 - loss: 0.3068 - val_RootMeanSquaredError: 0.5999 - val_loss: 0.3599
# Epoch 11/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.5500 - loss: 0.3026 - val_RootMeanSquaredError: 0.7630 - val_loss: 0.5821
# Epoch 12/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5462 - loss: 0.2984 - val_RootMeanSquaredError: 0.6244 - val_loss: 0.3898
# Epoch 13/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5435 - loss: 0.2955 - val_RootMeanSquaredError: 0.8120 - val_loss: 0.6593
# Epoch 14/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5409 - loss: 0.2927 - val_RootMeanSquaredError: 0.6775 - val_loss: 0.4590
# Epoch 15/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5372 - loss: 0.2887 - val_RootMeanSquaredError: 0.7124 - val_loss: 0.5075
# Epoch 16/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5338 - loss: 0.2851 - val_RootMeanSquaredError: 0.5760 - val_loss: 0.3318
# Epoch 17/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5310 - loss: 0.2821 - val_RootMeanSquaredError: 0.7454 - val_loss: 0.5556
# Epoch 18/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5286 - loss: 0.2795 - val_RootMeanSquaredError: 0.6720 - val_loss: 0.4515
# Epoch 19/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5275 - loss: 0.2784 - val_RootMeanSquaredError: 0.7075 - val_loss: 0.5005
# Epoch 20/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5250 - loss: 0.2757 - val_RootMeanSquaredError: 0.6243 - val_loss: 0.3898

# %%
mse_test, rmse_test = model.evaluate(X_test, y_test)
# Out:
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5286 - loss: 0.2796

# %%
import matplotlib
import matplotlib.pyplot as plt
y_pred = model.predict(X_test)
plt.scatter(y_pred,y_test)
# Out:
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
